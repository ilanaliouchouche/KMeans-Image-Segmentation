# %%
from mykmean import MyKMean
import numpy as np

# %%
mykmean = MyKMean("ping.jpg", np.arange(2,10))

# %%
mykmean.display_image()

# %%
mykmean.crop_img(slice(20,None), slice(200,500))

# %%
mykmean.display_image()

# %%
mykmean.display_rgb()

# %%
mykmean.set_DataFrame()

# %%
mykmean.df_img
# Out:
#           R    G    B
# 0         1   43   91
# 1         1   43   91
# 2         1   43   91
# 3         1   43   91
# 4         1   43   91
# ...     ...  ...  ...
# 102295  251  250  255
# 102296  248  248  250
# 102297  249  249  251
# 102298  250  250  252
# 102299  250  250  252
#
# [102300 rows x 3 columns]

# %%
mykmean.training()
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /home/ilan/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/ilan/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/ilan/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
mykmean.set_all_inertiaw()
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07101774215698242s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.2s finished

# %%
mykmean.display_elbow_plot(idx_marker=5)

# %%
mykmean.display_segmented_images()

# %%
mykmean.benchmark()

# %%
mykmean.display_benchmark()

# %%
mykmean.display_centroids()
